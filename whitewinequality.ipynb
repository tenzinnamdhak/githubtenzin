# %% [markdown]
# <a href="https://colab.research.google.com/github/tenzinnamdhak/githubtenzin/blob/main/whitewinequality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Data/winequality-white (1).csv')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.0              0.27         0.36  ...       0.45      8.8        6
# 1            6.3              0.30         0.34  ...       0.49      9.5        6
# 2            8.1              0.28         0.40  ...       0.44     10.1        6
# 3            7.2              0.23         0.32  ...       0.40      9.9        6
# 4            7.2              0.23         0.32  ...       0.40      9.9        6
#
# [5 rows x 12 columns]

# %%
data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 4893            6.2              0.21         0.29  ...       0.50     11.2        6
# 4894            6.6              0.32         0.36  ...       0.46      9.6        5
# 4895            6.5              0.24         0.19  ...       0.46      9.4        6
# 4896            5.5              0.29         0.30  ...       0.38     12.8        7
# 4897            6.0              0.21         0.38  ...       0.32     11.8        6
#
# [5 rows x 12 columns]

# %%
len(data)
# Out:
# 4898

# %%
data.shape
# Out:
# (4898, 12)

# %%
data.info() ## checking whether they have any null values or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fixed acidity          4898 non-null   float64
#  1   volatile acidity       4898 non-null   float64
#  2   citric acid            4898 non-null   float64
#  3   residual sugar         4898 non-null   float64
#  4   chlorides              4898 non-null   float64
#  5   free sulphur dioxide   4898 non-null   float64
#  6   total sulphur dioxide  4898 non-null   float64
#  7   density                4898 non-null   float64
#  8   pH                     4898 non-null   float64
#  9   sulphates              4898 non-null   float64
#  10  alcohol                4898 non-null   float64
#  11  quality                4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
data.describe() ## this function returns mean, median, standard deviation, min and max, quantiles of the data.
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    4898.000000       4898.000000  ...  4898.000000  4898.000000
# mean        6.854788          0.278241  ...    10.514267     5.877909
# std         0.843868          0.100795  ...     1.230621     0.885639
# min         3.800000          0.080000  ...     8.000000     3.000000
# 25%         6.300000          0.210000  ...     9.500000     5.000000
# 50%         6.800000          0.260000  ...    10.400000     6.000000
# 75%         7.300000          0.320000  ...    11.400000     6.000000
# max        14.200000          1.100000  ...    14.200000     9.000000
#
# [8 rows x 12 columns]

# %%
## we can from the above data, that mean is less than the median which is 50% (50 percentile)
## large  difference btw 75th % tile and max values of predictors such as 'residual sugar', 'free sulphur dioxide', 'total sulphur dioxide'.
## it suggests that there are extreme values-outliers in our dataset.

# %%
data.quality.unique() ## this dependent variable, 'quality' scores ranges from 1 being poor and 10 being the best.
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
data.quality.value_counts() ## this tells us vote count of each quality score in descending order. mostly it is concentrated betwen 5 - 7. there are few 3's and 9's.
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
data.isnull().sum() ## checking for null values
# Out:
# fixed acidity            0
# volatile acidity         0
# citric acid              0
# residual sugar           0
# chlorides                0
# free sulphur dioxide     0
# total sulphur dioxide    0
# density                  0
# pH                       0
# sulphates                0
# alcohol                  0
# quality                  0
# dtype: int64

# %%
## lets explore some graphs

# %%
## we will be using matplotlib and seaborn from the libraries.

# %%
## graphical representation gives us good insight of the univariate and mulitvariate analysis.

# %%
## to perform linear regression, we have to remove the correlated variables to improve our model. We cand find correlations using pandas.corr() function and find the correlation matrix using heatmap in seaborn.

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.0              0.27         0.36  ...       0.45      8.8        6
# 1            6.3              0.30         0.34  ...       0.49      9.5        6
# 2            8.1              0.28         0.40  ...       0.44     10.1        6
# 3            7.2              0.23         0.32  ...       0.40      9.9        6
# 4            7.2              0.23         0.32  ...       0.40      9.9        6
#
# [5 rows x 12 columns]

# %%
import seaborn
import matplotlib.pyplot as plt
import numpy as np

# %%
data.corr() ## this is correlation matrix
# Out:
#                        fixed acidity  volatile acidity  ...   alcohol   quality
# fixed acidity               1.000000         -0.022697  ... -0.120881 -0.113663
# volatile acidity           -0.022697          1.000000  ...  0.067718 -0.194723
# citric acid                 0.289181         -0.149472  ... -0.075729 -0.009209
# residual sugar              0.089021          0.064286  ... -0.450631 -0.097577
# chlorides                   0.023086          0.070512  ... -0.360189 -0.209934
# free sulphur dioxide       -0.049396         -0.097012  ... -0.250104  0.008158
# total sulphur dioxide       0.091070          0.089261  ... -0.448892 -0.174737
# density                     0.265331          0.027114  ... -0.780138 -0.307123
# pH                         -0.425858         -0.031915  ...  0.121432  0.099427
# sulphates                  -0.017143         -0.035728  ... -0.017433  0.053678
# alcohol                    -0.120881          0.067718  ...  1.000000  0.435575
# ...

# %%
plt.figure(figsize=(12, 12))
seaborn.heatmap(data.corr(), annot=True, cmap='coolwarm')

# %%
seaborn.pairplot(data, height=1.5)

# %%
data['residual sugar'].corr(data['density']) ## finding the correlation between 2 cols
# Out:
# 0.8389664549045835

# %%
data['free sulphur dioxide'].corr(data['quality']) ## finding the correlation between 2 cols
# Out:
# 0.008158067123436048

# %%
## we need to check if there is outlier in the features
## we also have to plot histogram 
## we also have to plot boxplot 
## we have to establish the relationship between alcohol and quality as this could help in the predictive model of quality. 
## we have to understand which one has negative correlatiion or zero correlation with the quality.
## we will do the bivariate analysis between quality and other 12 features / variables.

# %%
data['quality'].corr(data['alcohol'])
# Out:
# 0.43557471546165777

# %%
data['quality'].corr(data['density'])
# Out:
# -0.3071233127347302

# %%
data['quality'].corr(data['chlorides'])
# Out:
# -0.20993441094676024

# %%
data['quality'].corr(data['pH'])
# Out:
# 0.09942724573666417

# %%
data['quality'].corr(data['residual sugar'])
# Out:
# -0.09757682889469309

# %%
data['quality'].corr(data['fixed acidity'])
# Out:
# -0.11366283071301778

# %%
data['quality'].corr(data['volatile acidity'])
# Out:
# -0.19472296892113414

# %%
data['quality'].corr(data['citric acid'])
# Out:
# -0.009209090883975405

# %%
data['quality'].corr(data['free sulphur dioxide'])
# Out:
# 0.00815806712343605

# %%
data['quality'].corr(data['total sulphur dioxide'])
# Out:
# -0.17473721759706262

# %%
data['quality'].corr(data['sulphates'])
# Out:
# 0.053677877132792005

# %%
## why boxplots? 
## it tells u the values of your outliers.
## it tells you whether the data is symmetrical or not
## determine how tightly data is grouped
## see if your data is skewed

# %%
plt.figure(figsize= (10, 15))
for i, col in enumerate(list(data.columns.values)):
  plt.subplot(4, 3, i+1)
  data.boxplot(col)
  plt.grid()
  plt.tight_layout()
